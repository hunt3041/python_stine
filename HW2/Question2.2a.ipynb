# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
t = np.linspace(.1, .25, 10)
y = (6*t**3 - 3*t - 4)/(8*np.sin(5*t))

# %%
# Plot 
fig, chart = plt.subplots()
chart.plot(t, y)
plt.show()

print(type(chart))
# Out:
# <class 'matplotlib.axes._axes.Axes'>
